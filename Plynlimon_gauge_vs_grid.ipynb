# %% [markdown]
# # FDRI catchment gauge record vs gridded data at Carreg Wen
#
# The rain gauge record is from Carreg-wen, Pembrokeshire
#
# ## Table of contents
# [1 Compute flood events](#compute-flood-events)
# [2 Required functions](#functions-needed-to-plot-data)
# [3 Make plots](#make-plots)

# %%
import polars as pl
import xarray as xr

# %%
CARREG_COORDS = {"Easting": 282903, "Northing": 288549}

# %%
haduk_carreg = xr.open_mfdataset(['hadukgrid_data/hadukgrid_1km_plynlimon3by3_19760101_19920831.nc',\
                 'hadukgrid_data/hadukgrid_1km_plynlimon3by3_19920901_20091231.nc'])
haduk_carreg
# Out:
# <xarray.Dataset> Size: 2MB
# Dimensions:                       (time: 12419, projection_y_coordinate: 3,
#                                    projection_x_coordinate: 3, bnds: 2)
# Coordinates:
#   * time                          (time) datetime64[ns] 99kB 1976-01-01T12:00...
#   * projection_y_coordinate       (projection_y_coordinate) float64 24B 2.875...
#   * projection_x_coordinate       (projection_x_coordinate) float64 24B 2.815...
#     latitude                      (projection_y_coordinate, projection_x_coordinate) float64 72B dask.array<chunksize=(3, 3), meta=np.ndarray>
#     longitude                     (projection_y_coordinate, projection_x_coordinate) float64 72B dask.array<chunksize=(3, 3), meta=np.ndarray>
# Dimensions without coordinates: bnds
# Data variables:
#     rainfall                      (time, projection_y_coordinate, projection_x_coordinate) float64 894kB dask.array<chunksize=(6088, 3, 3), meta=np.ndarray>
# ...

# %%
gauge_carreg = pl.read_csv('gauge_data/plynlimon-jwk-2024-infilled_carreg_rf.csv', skip_rows=13,\
                          try_parse_dates=True, columns=[0, 1], new_columns=["datetime", "rain_mm"])
gauge_carreg.head()
# Out:
# shape: (5, 2)
# ┌─────────────────────┬─────────┐
# │ datetime            ┆ rain_mm │
# │ ---                 ┆ ---     │
# │ datetime[μs]        ┆ f64     │
# ╞═════════════════════╪═════════╡
# │ 1976-01-02 09:00:00 ┆ null    │
# │ 1976-01-03 09:00:00 ┆ 0.5     │
# │ 1976-01-04 09:00:00 ┆ 62.0    │
# │ 1976-01-05 09:00:00 ┆ 12.5    │
# │ 1976-01-06 09:00:00 ┆ 5.0     │
# └─────────────────────┴─────────┘

# %%
haduk_carreg_rainfall_mean = haduk_carreg['rainfall'].mean(('projection_x_coordinate', 'projection_y_coordinate'))

# %%
haduk_carreg['rainfall'].sel(projection_x_coordinate=282500, projection_y_coordinate=288500)
# Out:
# <xarray.DataArray 'rainfall' (time: 12419)> Size: 99kB
# dask.array<getitem, shape=(12419,), dtype=float64, chunksize=(6331,), chunktype=numpy.ndarray>
# Coordinates:
#   * time                     (time) datetime64[ns] 99kB 1976-01-01T12:00:00 ....
#     projection_y_coordinate  float64 8B 2.885e+05
#     projection_x_coordinate  float64 8B 2.825e+05
#     latitude                 float64 8B dask.array<chunksize=(), meta=np.ndarray>
#     longitude                float64 8B dask.array<chunksize=(), meta=np.ndarray>
# Attributes:
#     standard_name:  lwe_thickness_of_precipitation_amount
#     long_name:      Total rainfall
#     units:          mm
#     description:    Total rainfall
#     label_units:    mm
#     level:          NA
#     plot_label:     Total rainfall (mm)
#     cell_methods:   time: sum
#     grid_mapping:   transverse_mercator

# %%
haduk_carreg_rainfall_mean
# Out:
# <xarray.DataArray 'rainfall' (time: 12419)> Size: 99kB
# dask.array<mean_agg-aggregate, shape=(12419,), dtype=float64, chunksize=(6331,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 99kB 1976-01-01T12:00:00 ... 2009-12-31T12...
